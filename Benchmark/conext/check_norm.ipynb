# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
import os
import pickle

# %%
paris_long_clean=np.load('/home/jupyter-sergi/2023_02_03 - CoNEXT benchmark - shared/Paris_long/Apple iCloud_clean.npy')
paris_forecast_clean=np.load('/home/jupyter-sergi/2023_02_03 - CoNEXT benchmark - shared/Paris_forecast/Apple iCloud_clean.npy')
paris_forecast_preds=np.load('/home/jupyter-sergi/2023_02_03 - CoNEXT benchmark - shared/Paris_forecast/Apple iCloud_Alpha_0.75_Tdec_30min_prediction.npy')

# %%
print(f'Paris_long_clean: {paris_long_clean.shape}, Paris_forecast_clean: {paris_forecast_clean.shape}, Paris_forecast_preds: {paris_forecast_preds.shape}')
# Out:
# Paris_long_clean: (99093,), Paris_forecast_clean: (9481,), Paris_forecast_preds: (9481,)

# %%
syn_data_long=np.load('/home/jupyter-sergi/2023_02_03 - CoNEXT benchmark - shared/syn_data_long_Norm/emBB_0_agg_60_s.npy')
syn_data_forecast=np.load('/home/jupyter-sergi/syn_data_forecast/emBB_0_agg_60_s.npy')

# %%
with open('/home/jupyter-sergi/2023_02_03 - CoNEXT benchmark - shared/results/2023_02_13_30min_2daysHist_Synthetic_Dat1/results.pkl', 'rb') as f:
    x = pickle.load(f)
    z= pickle.load(f)

# %%
z.shape
# Out:
# (316, 20)

# %%
plt.plot(z)
